# %%
def printFieldsinAI():
    List_AI= ["Machine Learning", "Neural Network", "Vision", "Robotics", "Speech Procesing", 
"Natural Language Processing"]
    print("Sub-fields in AI are:")
    for fields in List_AI:
        print(fields)

# %%
printFieldsinAI()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Network
# Vision
# Robotics
# Speech Procesing
# Natural Language Processing

# %%
class SubFieldsinAI():
    def printFieldsinAI():
        List_AI= ["Machine Learning", "Neural Network", "Vision", "Robotics", "Speech Procesing", 
    "Natural Language Processing"]
        print("Sub-fields in AI are:")
        for fields in List_AI:
            print(fields)

# %%
SubFieldsinAI.printFieldsinAI()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Network
# Vision
# Robotics
# Speech Procesing
# Natural Language Processing
