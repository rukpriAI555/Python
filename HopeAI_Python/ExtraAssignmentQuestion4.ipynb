# %%
List_AI= ["Machine Learning", "Neural Network", "Vision", "Robotics", "Speech Procesing", 
"Natural Language Processing"]

# %%
for fields in List_AI:
    print(fields)
# Out:
# Machine Learning
# Neural Network
# Vision
# Robotics
# Speech Procesing
# Natural Language Processing

# %%
def printFieldsinAI():
    List_AI= ["Machine Learning", "Neural Network", "Vision", "Robotics", "Speech Procesing", 
"Natural Language Processing"]
    for fields in List_AI:
        print(fields)

# %%
printFieldsinAI()
# Out:
# Machine Learning
# Neural Network
# Vision
# Robotics
# Speech Procesing
# Natural Language Processing

# %%
oddoreven = int(input("Enter a Number:"))
if ((oddoreven%2)==0):
    print(oddoreven, "is Even Number")
else:
    print(oddoreven, "is Odd Number")
# Out:
# Enter a Number: 52452
# 52452 is Even Number

# %%
def OddEven():
    oddoreven = int(input("Enter a Number:"))
    if ((oddoreven%2)==0):
        print(oddoreven, "is Even Number")
    else:
        print(oddoreven, "is Odd Number")

# %%
OddEven()
# Out:
# Enter a Number: 52452
# 52452 is Even Number

# %%
Gender=input("Enter the gender:")
Age=int(input("Enter the age:"))
if (Gender=="male" and Age<21):
    print("Your Gender: ", Gender)
    print("Your Age: ", Age)
    print("Not Eligible")
elif (Gender=="male" and Age>20):
    print("Your Gender: ", Gender)
    print("Your Age: ", Age)
    print("Eligible")
elif(Gender=="female" and Age<18):
    print("Your Gender: ", Gender)
    print("Your Age: ", Age)
    print("Not Eligible")
elif(Gender=="female" and Age>17):
    print("Your Gender: ", Gender)
    print("Your Age: ", Age)
    print("Eligible")
else:
    pass
# Out:
# Enter the gender: female
# Enter the age: 70
# Your Gender:  female
# Your Age:  70
# Eligible

# %%
sub1 = int(input("Subject 1 = "))
sub2 = int(input("Subject 2 = "))
sub3 = int(input("Subject 3 = "))
sub4= int(input("Subject 4 = "))
sub5 = int(input("Subject 5 = "))
Total_Marks = sub1+sub2+sub3+sub4+sub5
Percentage = Total_Marks/500*100
#print("Subject 1 = ", sub1)
#print("Subject 2 = ", sub2)
#print("Subject 3 = ", sub3) 
#print("Subject 4 = ", sub4)
#print("Subject 5 = ", sub5)
print("Total: ", Total_Marks)
print("Percentage: ", Percentage)
# Out:
# Subject 1 =  98
# Subject 2 =  87
# Subject 3 =  95
# Subject 4 =  95
# Subject 5 =  93
# Total:  468
# Percentage:  93.60000000000001

# %%
#Height:32
#Breadth:34
#Area formula: (Height*Breadth)/2

#Area of Triangle: 544.0

#Height1:2
#Height2:4
#Breadth:4

#Perimeter formula: Height1+Height2+Breadth

#Perimeter of Triangle: 10

# %%
ht=int(input("Height: "))
br=int(input("Breadth: "))
Area=(ht*br)/2
print("Area of Triangle: ",Area)
ht1=int(input("Height1: "))
ht2=int(input("Height2: "))
br=int(input("Breadth: "))
Perimeter=ht1+ht2+br
print("Perimeter of Triangle: ", Perimeter)
# Out:
# Height:  32
# Breadth:  34
# Area of Triangle:  544.0
# Height1:  2
# Height2:  4
# Breadth:  4
# Perimeter of Triangle:  10
